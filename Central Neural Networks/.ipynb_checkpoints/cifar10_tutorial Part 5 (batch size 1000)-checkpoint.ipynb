# %%
# %matplotlib inline

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

batch_size = 500

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join(f'{classes[labels[j]]:5s}' for j in range(batch_size)))
# Out:
# horse bird  dog   bird  dog   horse bird  cat   frog  horse ship  car   truck cat   frog  deer  plane frog  dog   dog   plane ship  truck bird  frog  horse car   cat   deer  ship  cat   truck plane deer  frog  car   deer  ship  car   deer  cat   plane car   plane deer  dog   bird  deer  car   cat   car   truck bird  cat   bird  truck frog  ship  car   horse bird  cat   dog   deer  cat   truck truck cat   car   ship  ship  dog   frog  frog  plane deer  plane car   plane dog   cat   horse deer  truck dog   plane horse cat   deer  bird  bird  deer  truck car   ship  plane bird  frog  dog   car   cat   truck bird  bird  car   plane frog  plane cat   frog  dog   car   frog  deer  truck plane car   car   dog   dog   horse frog  bird  frog  deer  truck frog  truck horse bird  ship  cat   ship  ship  truck bird  deer  bird  ship  truck truck horse bird  car   horse ship  car   horse bird  deer  cat   horse bird  frog  frog  frog  ship  ship  ship  deer  plane frog  horse cat   cat   truck deer  plane frog  dog   bird  truck car   bird  dog   cat   truck plane dog   dog   ship  frog  dog   truck deer  cat   dog   horse ship  deer  dog   dog   truck truck truck dog   plane deer  frog  cat   cat   frog  plane truck car   bird  horse bird  plane truck car   truck truck horse frog  horse bird  cat   frog  deer  cat   plane frog  dog   ship  car   cat   plane plane truck deer  car   bird  car   car   bird  bird  plane bird  ship  horse frog  plane horse bird  horse bird  bird  cat   car   plane plane cat   frog  cat   frog  plane deer  bird  frog  frog  ship  truck deer  truck ship  cat   plane truck bird  truck truck cat   plane frog  dog   plane frog  plane bird  car   frog  deer  bird  ship  bird  cat   truck car   cat   dog   truck truck ship  truck dog   deer  horse car   truck frog  frog  horse plane frog  plane cat   ship  plane bird  frog  cat   bird  frog  truck dog   horse deer  deer  bird  dog   plane dog   dog   dog   bird  car   cat   plane dog   deer  frog  horse truck ship  bird  cat   dog   horse dog   deer  deer  cat   frog  ship  dog   dog   cat   truck horse ship  car   horse plane plane deer  car   dog   bird  ship  deer  ship  deer  horse truck car   ship  truck deer  plane plane dog   dog   bird  truck car   dog   bird  deer  cat   car   frog  car   truck dog   horse ship  cat   frog  plane truck dog   plane truck car   car   frog  dog   car   cat   car   cat   bird  cat   frog  bird  ship  truck frog  cat   ship  car   frog  truck dog   cat   ship  cat   horse dog   deer  cat   horse plane dog   frog  plane dog   cat   ship  dog   horse deer  plane ship  truck bird  truck ship  frog  bird  truck bird  deer  frog  ship  ship  deer  car   dog   ship  deer  car   plane car   cat   plane deer  dog   ship  ship  bird  dog   frog  ship  horse cat   bird  plane truck bird  dog   deer  frog  truck ship  deer  bird  truck cat   truck plane car   dog   frog  horse ship  cat   horse bird  ship  ship  bird  plane ship  ship  frog  truck bird  horse

# %%
import torch.nn as nn
import torch.nn.functional as F

# Use multiple layers alongside convolution layers beforehand to transition from input to 110 neurons to 74 neurons to 10 neurons
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 110)
        self.fc2 = nn.Linear(110, 74)
        self.fc3 = nn.Linear(74, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

net = Net()

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
# Lists to store metrics for plotting
loss_metric = []
training_accuracy = []
test_accuracy = []

# %%
for epoch in range(50):  # loop over the dataset multiple times

    # Statistics
    correct = 0
    total = 0
    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics and calculate accuracy
        running_loss += loss.item()
        if i % 2000 == 1999:    # print every 2000 mini-batches
            print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 2000:.3f}')
            running_loss = 0.0
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    # Record the training accuracy and loss
    epoch_loss = running_loss / len(trainloader)
    epoch_accuracy = correct / total
    loss_metric.append(epoch_loss)
    training_accuracy.append(epoch_accuracy)

    # Record the testing accuracy
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    acc = correct / total
    test_accuracy.append(acc)

print('Finished Training')
# Out:
# Finished Training

# %%
PATH = './cifar_net.pth'
torch.save(net.state_dict(), PATH)

# %%
dataiter = iter(testloader)
images, labels = next(dataiter)

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join(f'{classes[labels[j]]:5s}' for j in range(500)))
# Out:
# GroundTruth:  cat   ship  ship  plane frog  frog  car   frog  cat   car   plane truck dog   horse truck ship  dog   horse ship  frog  horse plane deer  truck dog   bird  deer  plane truck frog  frog  dog   deer  dog   truck bird  deer  car   truck dog   deer  frog  dog   frog  plane truck cat   truck horse frog  truck ship  plane cat   ship  ship  horse horse deer  frog  horse cat   frog  cat   frog  bird  car   bird  cat   horse bird  frog  ship  ship  plane bird  truck cat   cat   ship  ship  car   car   horse bird  dog   bird  horse ship  truck plane cat   ship  frog  deer  frog  frog  plane plane horse deer  dog   frog  cat   car   car   cat   frog  ship  horse deer  plane frog  bird  car   cat   plane deer  bird  horse ship  cat   car   bird  ship  plane ship  cat   dog   bird  deer  car   ship  truck car   bird  truck horse bird  truck frog  dog   frog  cat   ship  horse frog  bird  dog   bird  ship  truck frog  plane plane dog   bird  truck dog   deer  bird  car   frog  frog  ship  deer  ship  deer  dog   plane truck truck truck ship  truck truck cat   horse dog   plane plane dog   bird  bird  cat   ship  frog  cat   deer  plane dog   ship  plane car   horse bird  ship  ship  horse ship  dog   car   ship  horse car   cat   plane dog   horse truck horse deer  dog   truck ship  plane horse truck ship  bird  horse frog  truck deer  cat   truck frog  deer  horse frog  dog   car   dog   ship  ship  plane deer  plane dog   dog   car   car   ship  truck plane cat   car   truck bird  bird  dog   cat   truck truck deer  plane cat   plane plane truck ship  car   dog   horse plane ship  bird  deer  horse plane bird  cat   frog  cat   ship  dog   plane cat   deer  cat   truck plane frog  car   plane truck car   plane horse truck car   bird  frog  truck cat   deer  frog  plane plane frog  frog  frog  cat   bird  frog  car   ship  bird  car   frog  ship  frog  ship  plane deer  plane horse horse dog   dog   cat   dog   bird  cat   deer  car   horse dog   deer  frog  car   truck cat   frog  frog  truck cat   ship  plane horse bird  frog  bird  dog   ship  dog   deer  frog  ship  truck truck car   plane bird  bird  horse cat   bird  ship  plane truck dog   ship  car   truck deer  car   cat   ship  car   deer  horse truck deer  bird  horse plane horse plane frog  frog  truck plane truck bird  ship  horse bird  bird  dog   car   bird  frog  bird  truck frog  bird  cat   plane cat   truck ship  horse ship  ship  deer  plane car   ship  bird  horse truck cat   frog  car   truck plane horse cat   horse deer  dog   plane plane bird  truck cat   deer  plane frog  bird  dog   cat   horse cat   horse bird  dog   cat   car   car   deer  truck truck dog   horse dog   plane bird  bird  bird  truck horse cat   truck deer  cat   dog   deer  frog  dog   frog  car   deer  cat   deer  deer  cat   horse ship  cat   horse ship  plane dog   horse frog  plane dog   deer  ship  frog  ship  dog   dog   truck truck truck dog   plane car   plane ship  car   car   ship  plane bird  bird  plane

# %%
net = Net()
net.load_state_dict(torch.load(PATH, weights_only=True))
# Out:
# <All keys matched successfully>

# %%
outputs = net(images)

# %%
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join(f'{classes[predicted[j]]:5s}'
                              for j in range(500)))
# Out:
# Predicted:  cat   ship  car   ship  bird  frog  car   frog  dog   car   ship  truck frog  horse truck plane dog   cat   ship  horse horse plane plane truck horse frog  frog  horse truck frog  frog  horse deer  frog  truck cat   frog  car   truck dog   truck frog  cat   frog  plane truck frog  truck deer  frog  truck ship  frog  frog  ship  ship  horse truck horse deer  deer  frog  horse bird  frog  frog  car   plane frog  truck deer  frog  ship  ship  truck bird  truck cat   cat   plane ship  car   plane horse bird  horse bird  ship  ship  truck ship  deer  ship  bird  deer  frog  frog  bird  horse truck deer  cat   frog  frog  car   ship  ship  frog  cat   dog   frog  plane frog  bird  car   horse plane horse frog  horse ship  horse bird  bird  plane frog  truck dog   cat   plane deer  truck truck truck car   cat   truck horse bird  ship  frog  dog   cat   horse ship  deer  frog  horse cat   dog   car   truck truck ship  bird  cat   bird  truck cat   deer  bird  car   frog  frog  truck horse ship  frog  horse truck truck truck car   ship  truck truck bird  frog  cat   truck truck horse frog  bird  horse ship  frog  frog  horse plane frog  car   truck car   horse deer  ship  cat   horse cat   cat   truck ship  truck car   cat   ship  dog   horse ship  horse car   cat   truck truck plane horse truck plane horse horse frog  truck deer  dog   truck cat   frog  bird  truck dog   truck horse car   ship  plane frog  truck frog  cat   car   car   truck horse plane frog  horse ship  bird  car   horse dog   frog  truck deer  truck frog  car   truck car   ship  truck horse frog  plane ship  horse deer  horse plane bird  cat   frog  dog   ship  bird  car   horse horse dog   ship  car   cat   car   truck truck car   plane horse truck car   bird  frog  car   dog   deer  frog  plane plane frog  frog  frog  horse dog   bird  ship  ship  bird  car   deer  ship  frog  plane plane dog   horse horse horse dog   dog   dog   dog   frog  bird  frog  truck deer  dog   plane frog  ship  truck deer  frog  frog  frog  cat   ship  plane horse cat   horse bird  horse ship  dog   horse cat   ship  truck truck car   ship  bird  frog  dog   deer  cat   car   car   horse dog   ship  plane truck plane truck truck plane car   deer  horse truck bird  bird  horse ship  dog   frog  frog  frog  truck plane truck bird  plane horse deer  cat   dog   car   plane frog  dog   horse frog  dog   cat   ship  truck frog  car   horse ship  truck deer  plane truck plane bird  horse plane dog   frog  car   truck horse truck dog   horse frog  horse ship  bird  bird  truck dog   horse truck frog  dog   dog   dog   frog  truck horse bird  bird  dog   car   car   deer  truck truck horse deer  bird  plane bird  bird  frog  truck horse dog   truck deer  bird  horse frog  truck dog   frog  car   dog   horse frog  horse cat   horse ship  deer  car   ship  plane horse horse deer  plane bird  horse truck frog  plane dog   frog  truck truck truck dog   plane car   car   plane car   ship  plane car   bird  bird  plane

# %%
correct = 0
total = 0
# since we're not training, we don't need to calculate the gradients for our outputs
with torch.no_grad():
    for data in testloader:
        images, labels = data
        # calculate outputs by running images through the network
        outputs = net(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy of the network on the 10000 test images: {100 * correct // total} %')
# Out:
# Accuracy of the network on the 10000 test images: 48 %

# %%
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

# again no gradients needed
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[classes[label]] += 1
            total_pred[classes[label]] += 1


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
# Out:
# Accuracy for class: plane is 50.0 %
# Accuracy for class: car   is 65.4 %
# Accuracy for class: bird  is 37.1 %
# Accuracy for class: cat   is 27.0 %
# Accuracy for class: deer  is 26.0 %
# Accuracy for class: dog   is 38.9 %
# Accuracy for class: frog  is 63.9 %
# Accuracy for class: horse is 62.4 %
# Accuracy for class: ship  is 52.8 %
# Accuracy for class: truck is 59.4 %

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)
# Out:
# cuda:0

# %%
# Plotting the results
epochs = range(1, 51)

plt.plot(epochs, loss_metric)
plt.title('Loss')
plt.show()

plt.plot(epochs, training_accuracy)
plt.title('Training Accuracy')
plt.show()

plt.plot(epochs, test_accuracy)
plt.title('Test Accuracy')
plt.show()

# %% [markdown]
# When the batch size is 500, it seems that the graphs for loss and accuracies are much more linear than when compared to lower batch sizes. This is because the gradients estimates will be much more stable since more images are being trained per batch, and the improvement per epoch will be much more consistent.

# %%
del dataiter
